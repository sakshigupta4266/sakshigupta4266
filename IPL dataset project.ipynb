# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# we create array
import numpy as np
s=np.array([1,2,3,4,5])
print(s)
# Out:
# [1 2 3 4 5]

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

zpoint=['sakshi','rohit','ravi']
ypoint=[5000,3000,1000]

plt.plot(zpoint,ypoint,marker='o',color='yellow')
plt.title('Salary Graph')
plt.xlabel("Name")
plt.ylabel("Salary")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# import pandas as pd
# df=pd.read_csv(r'C:\Users\HP\Downloads\IPL_2022_21042023.csv')
# df.head

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\HP\Downloads\IPL_2022_21042023.csv')
df.head()
# Out:
#   CAT  CNT  POS NAME  CRD  ANNOUNCED2  RUNS2  4S2  6S1  6S2  ... E/R2  CATCH1  \
# 0  BW  CSK    9  DBV  8.5           4      0    0  0.0    0  ...  4.0       0
# 1  WK  CSK    7  MSD  8.5           4     50    7  1.0    2  ...  0.0       1
# 2  AR  CSK    5  RJD  9.5           4     26    0  1.0    2  ...  2.0       1
# 3  BT  CSK    3  RUT  8.5           4     28    2  2.0    4  ...  0.0       0
# 4  BT  CSK    4  ARD  9.0           4     15    1  1.0    2  ...  0.0       1
#
#    CATCH2 CATCH BONUS1  CATCH BONUS2  RUNOUT/STUMPING1  RUNOUT/STUMPING2  \
# 0       0          0.0             0                 0                 0
# 1       8          0.0             0                 0                 0
# 2       8          0.0             0                 0                 0
# 3       0          0.0             0                 0                 0
# 4       8          0.0             0                 0                 0
#
#    TOTAL  OPPOSITE TEAM  DT
# 0     87            KOL   1
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot 2

x=np.array([0,1,2,3])
y=np.array([50,60,70,80])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,4,5,6,7,8,9,])
y=np.array([86,87,88,89,90,91,92])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","mango","grapes"])
y=np.array([2,3,4,5,])

plt.bar(x,y)
plt.show()

# %% [raw]
# import numpy as np
#
# x= np.random.normal(25, 5, 75 )
# print(x)

# %%
import numpy as np

x= np.random.normal(25, 5, 75 )
print(x)
# Out:
# [25.63744773 24.83205345 19.44465125 21.17252705 28.34670748 25.3153768
#  23.9135696  31.36634903 29.07384611 25.50177444 34.10203578 30.13508439
#  26.51479485 17.78808192 28.66875826 24.19643983 26.79478076 23.40007095
#  30.11278404 22.11497314 24.60030972 26.2251959  31.98839143 19.74805364
#  25.32430504 31.08860159 26.63962047 26.36570712 25.11829132 31.35890869
#  27.86564125 33.48176019 29.33957046 19.58274336 22.92525282 32.5357914
#  25.05343798 26.63212465 18.78870748 37.01503598 30.39892032 32.66502253
#  23.43477723 18.38473199 32.52966927 27.46059558 22.22446699 24.21439885
#  26.11791361 13.87278258 23.6854596  33.7575759  33.29119259 18.24063675
#  31.53456978 21.43491558 24.26413093 32.26654917 32.64236707 16.38365422
#  18.59912869 33.11421149 26.36520623 31.29250435 23.23788154 14.77371721
#  18.36808042 25.94370985 22.55544328 21.26680041 21.54585359 25.01717538
#  16.38118648 26.63689273 20.60774628]

# %%
import numpy as np

x= np.random.normal(25, 5, 75 )
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

z=np.array([10,20,30,40,50])
plt.pie(z)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

z=np.array([10,20,30,40,50])
mylabels = (["a","b","c","d","e"])
myexplode = ([0.2,0,0,0,0])
mycolors = (["pink","green","yellow","orange","black"])
plt.pie(z , labels = mylabels , explode = myexplode, shadow = True , colors = mycolors )
plt.show()
