# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img = cv2.imread(r'C:\Users\HP\Pictures\sakshi1.jpg')
im = cv2.resize(img,(300,500))
cv2.imshow('My Image', im)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow("webcam", frame)

    if cv2.waitKey(1) & 0xFF == ord('a'):
       break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)

while True:
   ret, frame = cap.read()
   if not ret:
       print("Camera se frame nahi mila.")
       break
   gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
   faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
   for (x, y, w, h) in faces:
       cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

       cv2.putText(frame, f'People Count: {len(faces)}', (20, 40),
                  cv2.FONT_HERSHEY_SIMPLEX, 1, (225, 0, 0), 2)
       cv2.imshow('Laptop Camera - Face Counter', frame)
       if cv2.waitKey(1) == ord('q'):
           breaka

cap.release()
cv2.destroyAllWindows()q
