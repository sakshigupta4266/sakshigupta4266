# %%
def calculate_grade(marks):
    if marks >= 90:
        return 'A'
    elif marks >= 80:
        return 'B'
    elif marks >= 70:
        return 'C'
    elif marks >= 60:
        return 'D'
    else:
        return 'F'

file_name = "student_grades.txt"
with open(file_name, "w") as file:
    file.write("Student Grade Report\n")
    file.write("\n")
num_students = int(input("Enter number of students: "))
for i in range(num_students):
    print(f"\nEntering data for student {i + 1}")
    name = input("Enter student name: ")
    marks = float(input("Enter marks (0-100): "))
    if marks < 0 or marks > 100:
        print("Invalid marks! Please enter between 0 and 100.")
        continue

    grade = calculate_grade(marks)
    print(f"{name} has scored {marks} and recieved Grade: {grade}")
    with open(file_name, "a") as file:
        file.write(f"{name} - Marks: {marks} - Grade: {grade}\n")
        
print("\nAll students data saved to 'student_grades.txt'")

print("Student Name: Rohan")

sub1 = float(input("Enter Marks for Subject 1 (out of 100): "))
sub2 = float(input("Enter Marks for Subject 2 (out of 100): "))
sub3 = float(input("Enter Marks for Subject 3 (out of 100): "))

total = sub1 + sub2 + sub3

if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
     grade = "F"

print(f"Total Marks: {total} / 300") 
print(f"Grade:{grade}")
# Out:
# Enter number of students:  100
# Entering data for student 1
# Enter student name:  rohan
# Enter marks (0-100):  40
# rohan has scored 40.0 and recieved Grade: F
#
# Entering data for student 2
# Enter student name:  sakshi
# Enter marks (0-100):  65
# sakshi has scored 65.0 and recieved Grade: D
#
# Entering data for student 3
# Enter student name:  abhi
# Enter marks (0-100):  80
# abhi has scored 80.0 and recieved Grade: B
#
# Entering data for student 4
