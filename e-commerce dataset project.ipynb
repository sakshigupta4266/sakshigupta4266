# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\HP\Downloads\archive (3)\ecommerce_dataset_updated.csv')
print(df.head(10))
# Out:
#     User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 0  337c166f  f414122f-e          Sports        36.53            15
# 1  d38a19bf  fde50f9c-5        Clothing       232.79            20
# 2  d7f5f0b0  0d96fc90-3          Sports       317.02            25
# 3  395d4994  964fc44b-d            Toys       173.19            25
# 4  a83c145c  d70e2fc6-e          Beauty       244.80            20
# 5  3fdcdae8  0816ee12-5           Books       241.86            50
# 6  12772337  d41e0b55-c            Toys        76.91             5
# 7  9f0194af  83b7dc04-5          Sports       213.23            20
# 8  7a8559d8  87c9c896-1          Sports       379.81             5
# 9  8911f0d1  31308875-b  Home & Kitchen       415.36            50
#
#    Final_Price(Rs.) Payment_Method Purchase_Date
# 0             31.05    Net Banking    12-11-2024
# 1            186.23    Net Banking    09-02-2024
# 2            237.76    Credit Card    01-09-2024
# ...

# %%
print(df.isnull().sum())
# Out:
# User_ID             0
# Product_ID          0
# Category            0
# Price (Rs.)         0
# Discount (%)        0
# Final_Price(Rs.)    0
# Payment_Method      0
# Purchase_Date       0
# dtype: int64

# %%
print("Basic Info:\n", df.info())
print("\nDescriptive Stats:\n", df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           10 non-null     object
#  1   Product_ID        10 non-null     object
#  2   Category          10 non-null     object
#  3   Price (Rs.)       10 non-null     float64
#  4   Discount (%)      10 non-null     int64
#  5   Final_Price(Rs.)  10 non-null     float64
#  6   Payment_Method    10 non-null     object
#  7   Purchase_Date     10 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 772.0+ bytes
# Basic Info:
#  None
#
# Descriptive Stats:
#         Price (Rs.)  Discount (%)  Final_Price(Rs.)        Purchase_Date
# count    10.000000       10.0000         10.000000                   10
# mean    233.150000       23.5000        171.384000  2024-05-27 04:48:00
# ...

# %%
# top 10 sales name
category_sales = df['Category'].value_counts()
print("\nTop Categories:\n", category_sales)
# Out:
# Top Categories:
#  Category
# Sports            4
# Toys              2
# Clothing          1
# Beauty            1
# Books             1
# Home & Kitchen    1
# Name: count, dtype: int64

# %%
revenue_by_category = df.groupby('Category')['Final_Price(Rs.)'].sum().sort_values(ascending=False)
print("\nRevenue by Category:\n", revenue_by_category)
# Out:
# Revenue by Category:
#  Category
# Sports            800.21
# Home & Kitchen    207.68
# Toys              202.95
# Beauty            195.84
# Clothing          186.23
# Books             120.93
# Name: Final_Price(Rs.), dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=revenue_by_category.index, y=revenue_by_category.values)
plt.title("Total Revenue by Category")
plt.ylabel("Revenue (Rs.)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
payment_methods = df['Payment_Method'].value_counts()
print("\nPayment Method Distribution:\n", payment_methods)
# Out:
# Payment Method Distribution:
#  Payment_Method
# Net Banking    4
# Credit Card    3
# UPI            2
# Net            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
payment_methods.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Payment Method Share")
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
avg_discount = df.groupby('Category')['Discount (%)'].mean().sort_values(ascending=False)
print("\nAverage Discount by Category:\n", avg_discount)
# Out:
# Average Discount by Category:
#  Category
# Books             50.00
# Home & Kitchen    50.00
# Beauty            20.00
# Clothing          20.00
# Sports            16.25
# Toys              15.00
# Name: Discount (%), dtype: float64
